# %% [markdown]
# # Assignment #

# %% [markdown]
# # Data Processing with Pandas #

# %%
import pandas as pd
d=pd.read_csv("Olympic_Tokyo_2021_Complete_Dataset.csv")
df=pd.DataFrame(d)
print(d)
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode      Continent
# 0     113              1     USA  North America
# 1      88              2     CHN           Asia
# 2      58              5     JPN           Asia
# 3      65              4     GBR         Europe
# 4      71              3     ROC    Europe/Asia
# ..    ...            ...     ...            ...
# 88      1             77     GHA         Africa
# 89      1             77     GRN  North America
# 90      1             77     KUW         Africa
# 91      1             77     MDA           Asia
# 92      1             77     SYR           Asia
#
# [93 rows x 9 columns]

# %%
# Display the first 5 rows of the dataset
df.head()
# Out:
#    Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 2     3                       Japan          27            14            17
# 3     4               Great Britain          22            21            22
# 4     5                         ROC          20            28            23
#
#    Total  Rank by Total NOCCode      Continent
# 0    113              1     USA  North America
# 1     88              2     CHN           Asia
# 2     58              5     JPN           Asia
# 3     65              4     GBR         Europe
# 4     71              3     ROC    Europe/Asia

# %%
# Describe the dataset
df.describe()
# Out:
#             Rank  Gold Medal  Silver Medal  Bronze Medal       Total  \
# count  93.000000   93.000000     93.000000     93.000000   93.000000
# mean   46.333333    3.655914      3.634409      4.322581   11.612903
# std    26.219116    7.022471      6.626339      6.210372   19.091332
# min     1.000000    0.000000      0.000000      0.000000    1.000000
# 25%    24.000000    0.000000      0.000000      1.000000    2.000000
# 50%    46.000000    1.000000      1.000000      2.000000    4.000000
# 75%    70.000000    3.000000      4.000000      5.000000   11.000000
# max    86.000000   39.000000     41.000000     33.000000  113.000000
#
#        Rank by Total
# count      93.000000
# mean       43.494624
# std        24.171769
# min         1.000000
# 25%        23.000000
# 50%        47.000000
# 75%        66.000000
# max        77.000000

# %%
#describe the dataset
df.tail()
# Out:
#     Rank              Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88    86                 Ghana           0             0             1      1
# 89    86               Grenada           0             0             1      1
# 90    86                Kuwait           0             0             1      1
# 91    86   Republic of Moldova           0             0             1      1
# 92    86  Syrian Arab Republic           0             0             1      1
#
#     Rank by Total NOCCode      Continent
# 88             77     GHA         Africa
# 89             77     GRN  North America
# 90             77     KUW         Africa
# 91             77     MDA           Asia
# 92             77     SYR           Asia

# %%
# Check for missing values
df.isna().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold Medal       0
# Silver Medal     0
# Bronze Medal     0
# Total            0
# Rank by Total    0
# NOCCode          0
# Continent        0
# dtype: int64

# %%
df.sort_values("Gold Medal",ascending=False)
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 68    69                     Armenia           0             2             2
# 67    68          Dominican Republic           0             3             2
# 66    67                  Azerbaijan           0             3             4
# 65    66                    Colombia           0             4             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode      Continent
# 0     113              1     USA  North America
# 1      88              2     CHN           Asia
# 2      58              5     JPN           Asia
# 3      65              4     GBR         Europe
# 4      71              3     ROC    Europe/Asia
# ..    ...            ...     ...            ...
# 68      4             47     ARM         Europe
# 67      5             42     DOM  North America
# 66      7             33     AZE         Europe
# 65      5             42     COL  South America
# 92      1             77     SYR           Asia
#
# [93 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Rank', 'Team/NOC', 'Gold Medal', 'Silver Medal', 'Bronze Medal',
#        'Total', 'Rank by Total', 'NOCCode', 'Continent'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Rank  Gold Medal  Silver Medal  Bronze Medal       Total  \
# count  93.000000   93.000000     93.000000     93.000000   93.000000
# mean   46.333333    3.655914      3.634409      4.322581   11.612903
# std    26.219116    7.022471      6.626339      6.210372   19.091332
# min     1.000000    0.000000      0.000000      0.000000    1.000000
# 25%    24.000000    0.000000      0.000000      1.000000    2.000000
# 50%    46.000000    1.000000      1.000000      2.000000    4.000000
# 75%    70.000000    3.000000      4.000000      5.000000   11.000000
# max    86.000000   39.000000     41.000000     33.000000  113.000000
#
#        Rank by Total
# count      93.000000
# mean       43.494624
# std        24.171769
# min         1.000000
# 25%        23.000000
# 50%        47.000000
# 75%        66.000000
# max        77.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode      Continent
# 0     113              1     USA  North America
# 1      88              2     CHN           Asia
# 2      58              5     JPN           Asia
# 3      65              4     GBR         Europe
# 4      71              3     ROC    Europe/Asia
# ..    ...            ...     ...            ...
# 88      1             77     GHA         Africa
# 89      1             77     GRN  North America
# 90      1             77     KUW         Africa
# 91      1             77     MDA           Asia
# 92      1             77     SYR           Asia
#
# [93 rows x 9 columns]>

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode      Continent
# 0     113              1     USA  North America
# 1      88              2     CHN           Asia
# 2      58              5     JPN           Asia
# 3      65              4     GBR         Europe
# 4      71              3     ROC    Europe/Asia
# ..    ...            ...     ...            ...
# 88      1             77     GHA         Africa
# 89      1             77     GRN  North America
# 90      1             77     KUW         Africa
# 91      1             77     MDA           Asia
# 92      1             77     SYR           Asia
#
# [93 rows x 9 columns]>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode      Continent
# 0     113              1     USA  North America
# 1      88              2     CHN           Asia
# 2      58              5     JPN           Asia
# 3      65              4     GBR         Europe
# 4      71              3     ROC    Europe/Asia
# ..    ...            ...     ...            ...
# 88      1             77     GHA         Africa
# 89      1             77     GRN  North America
# 90      1             77     KUW         Africa
# 91      1             77     MDA           Asia
# 92      1             77     SYR           Asia
#
# [93 rows x 9 columns]>

# %%
df.columns =df.columns.str.strip()

# %%
df.isnull().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold Medal       0
# Silver Medal     0
# Bronze Medal     0
# Total            0
# Rank by Total    0
# NOCCode          0
# Continent        0
# dtype: int64

# %%
df.shape
# Out:
# (93, 9)

# %%
df.dropna().shape
# Out:
# (93, 9)

# %%
df.dropna (how="all").shape
# Out:
# (93, 9)
